# %% [markdown]
# # Part 2 - Data Science with Python
#
# ## Packages, EDA, Visualization and Web Scraping
#
# **Student Name:** Sagar Das
# **Project:** Student Performance Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", plt.matplotlib.__version__)
print("Seaborn version:", sns.__version__)
# Out:
# NumPy version: 2.5.3
# Pandas version: 3.0.6
# Matplotlib version: 3.11.2
# Seaborn version: 0.13.2

# %%
# NumPy demonstration

numbers = np.array([10, 20, 30, 40, 50])

print("Array:", numbers)
print("Mean:", np.mean(numbers))
print("Maximum:", np.max(numbers))
print("Minimum:", np.min(numbers))
# Out:
# Array: [10 20 30 40 50]
# Mean: 30.0
# Maximum: 50
# Minimum: 10

# %%
# Pandas demonstration

data = {
    "Name": ["Rahul", "Priya", "Arun", "Sneha"],
    "Marks": [85, 92, 76, 88]
}

df_demo = pd.DataFrame(data)

print("DataFrame:")
display(df_demo)

print("Average marks:", df_demo["Marks"].mean())
print("Highest marks:", df_demo["Marks"].max())
print("Number of students:", df_demo.shape[0])
# Out:
# DataFrame:
#     Name  Marks
# 0  Rahul     85
# 1  Priya     92
# 2   Arun     76
# 3  Sneha     88
# Average marks: 85.25
# Highest marks: 92
# Number of students: 4

# %%
# Matplotlib demonstration

students = ["Rahul", "Priya", "Arun", "Sneha"]
marks = [85, 92, 76, 88]

plt.bar(students, marks)
plt.title("Student Marks")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %%
# Seaborn demonstration

sns.set_theme()

sns.histplot(marks, bins=4)
plt.title("Distribution of Student Marks")
plt.xlabel("Marks")
plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
# # 2. Dataset Understanding
#
# ## Student Performance Dataset
#
# The Student Performance dataset is used to analyze student academic performance and identify patterns and relationships among the available variables.

# %%
# Display settings

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 1000)

print("Pandas is ready for dataset analysis.")
# Out:
# Pandas is ready for dataset analysis.

# %%
print("Jupyter is working correctly")
# Out:
# Jupyter is working correctly

# %%
# Load the Student Performance dataset

df = pd.read_csv("../Dataset/student-mat.csv", sep=";")

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason guardian  traveltime  studytime  failures schoolsup famsup paid activities nursery higher internet romantic  famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  course   mother           2          2         0       yes     no   no         no     yes    yes       no       no       4         3      4     1     1       3         6   5   6   6
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  course   father           1          2         0        no    yes   no         no      no    yes      yes       no       5         3      3     1     1       3         4   5   5   6
# ...

# %%
# Display the last 5 rows
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  reason guardian  traveltime  studytime  failures schoolsup famsup paid activities nursery higher internet romantic  famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 390     MS   M   20       U     LE3       A     2     2  services  services  course    other           1          2         2        no    yes  yes         no     yes    yes       no       no       5         5      4     4     5       4        11   9   9   9
# 391     MS   M   17       U     LE3       T     3     1  services  services  course   mother           2          1         0        no     no   no         no      no    yes      yes       no       2         4      5     3     4       2         3  14  16  16
# ...

# %%
# Display number of rows and columns
print("Rows and columns:", df.shape)
# Out:
# Rows and columns: (395, 33)

# %%
# Display all column names
print("Column names:")
print(df.columns.tolist())
# Out:
# Column names:
# ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']

# %%
# Display dataset information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    str
#  1   sex         395 non-null    str
#  2   age         395 non-null    int64
#  3   address     395 non-null    str
#  4   famsize     395 non-null    str
#  5   Pstatus     395 non-null    str
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    str
#  9   Fjob        395 non-null    str
#  10  reason      395 non-null    str
#  11  guardian    395 non-null    str
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    str
#  16  famsup      395 non-null    str
#  17  paid        395 non-null    str
#  18  activities  395 non-null    str
#  19  nursery     395 non-null    str
# ...

# %%
# Statistical summary of numerical columns
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures      famrel    freetime       goout        Dalc        Walc      health    absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177    3.944304    3.235443    3.108861    1.481013    2.291139    3.554430    5.708861   10.908861   10.713924   10.415190
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651    0.896659    0.998862    1.113278    0.890741    1.287897    1.390303    8.003096    3.319195    3.761505    4.581443
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000    1.000000    1.000000    1.000000    1.000000    1.000000    1.000000    0.000000    3.000000    0.000000    0.000000
# ...

# %%
# Check for missing values

missing_values = df.isnull().sum()

print("Missing values in each column:")
print(missing_values)

print("\nTotal missing values:", missing_values.sum())
# Out:
# Missing values in each column:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64
#
# Total missing values: 0

# %%
# Check for duplicate rows

duplicate_count = df.duplicated().sum()

print("Number of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 0

# %%
# Check data types

print("Data types of each column:")
print(df.dtypes)
# Out:
# Data types of each column:
# school          str
# sex             str
# age           int64
# address         str
# famsize         str
# Pstatus         str
# Medu          int64
# Fedu          int64
# Mjob            str
# Fjob            str
# reason          str
# guardian        str
# traveltime    int64
# studytime     int64
# failures      int64
# schoolsup       str
# famsup          str
# paid            str
# activities      str
# nursery         str
# higher          str
# internet        str
# romantic        str
# famrel        int64
# freetime      int64
# goout         int64
# Dalc          int64
# Walc          int64
# health        int64
# absences      int64
# G1            int64
# G2            int64
# G3            int64
# dtype: object

# %%
# Check unique values in selected categorical columns

categorical_columns = [
    "school", "sex", "address", "famsize",
    "Pstatus", "Mjob", "Fjob", "reason", "guardian"
]

for column in categorical_columns:
    print(f"\n{column}:")
    print(df[column].unique())
# Out:
# school:
# <StringArray>
# ['GP', 'MS']
# Length: 2, dtype: str
#
# sex:
# <StringArray>
# ['F', 'M']
# Length: 2, dtype: str
#
# address:
# <StringArray>
# ['U', 'R']
# Length: 2, dtype: str
#
# famsize:
# <StringArray>
# ['GT3', 'LE3']
# Length: 2, dtype: str
#
# Pstatus:
# <StringArray>
# ['A', 'T']
# Length: 2, dtype: str
#
# Mjob:
# <StringArray>
# ['at_home', 'health', 'other', 'services', 'teacher']
# Length: 5, dtype: str
#
# Fjob:
# <StringArray>
# ['teacher', 'other', 'services', 'health', 'at_home']
# Length: 5, dtype: str
#
# reason:
# <StringArray>
# ['course', 'other', 'home', 'reputation']
# Length: 4, dtype: str
#
# guardian:
# <StringArray>
# ['mother', 'father', 'other']
# Length: 3, dtype: str

# %%
# Check numerical columns for possible outliers

numerical_columns = [
    "age", "Medu", "Fedu", "studytime",
    "failures", "absences", "G1", "G2", "G3"
]

df[numerical_columns].describe()
# Out:
#               age        Medu        Fedu   studytime    failures    absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    2.035443    0.334177    5.708861   10.908861   10.713924   10.415190
# std      1.276043    1.094735    1.088201    0.839240    0.743651    8.003096    3.319195    3.761505    4.581443
# min     15.000000    0.000000    0.000000    1.000000    0.000000    0.000000    3.000000    0.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    0.000000    0.000000    8.000000    9.000000    8.000000
# 50%     17.000000    3.000000    2.000000    2.000000    0.000000    4.000000   11.000000   11.000000   11.000000
# 75%     18.000000    4.000000    3.000000    2.000000    0.000000    8.000000   13.000000   13.000000   14.000000
# ...

# %%
duplicate_count = df.duplicated().sum()
print("Number of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 0

# %%
print("Data types of each column:")
print(df.dtypes)
# Out:
# Data types of each column:
# school          str
# sex             str
# age           int64
# address         str
# famsize         str
# Pstatus         str
# Medu          int64
# Fedu          int64
# Mjob            str
# Fjob            str
# reason          str
# guardian        str
# traveltime    int64
# studytime     int64
# failures      int64
# schoolsup       str
# famsup          str
# paid            str
# activities      str
# nursery         str
# higher          str
# internet        str
# romantic        str
# famrel        int64
# freetime      int64
# goout         int64
# Dalc          int64
# Walc          int64
# health        int64
# absences      int64
# G1            int64
# G2            int64
# G3            int64
# dtype: object

# %%
categorical_columns = [
    "school", "sex", "address", "famsize",
    "Pstatus", "Mjob", "Fjob", "reason", "guardian"
]

for column in categorical_columns:
    print(f"\n{column}:")
    print(df[column].unique())
# Out:
# school:
# <StringArray>
# ['GP', 'MS']
# Length: 2, dtype: str
#
# sex:
# <StringArray>
# ['F', 'M']
# Length: 2, dtype: str
#
# address:
# <StringArray>
# ['U', 'R']
# Length: 2, dtype: str
#
# famsize:
# <StringArray>
# ['GT3', 'LE3']
# Length: 2, dtype: str
#
# Pstatus:
# <StringArray>
# ['A', 'T']
# Length: 2, dtype: str
#
# Mjob:
# <StringArray>
# ['at_home', 'health', 'other', 'services', 'teacher']
# Length: 5, dtype: str
#
# Fjob:
# <StringArray>
# ['teacher', 'other', 'services', 'health', 'at_home']
# Length: 5, dtype: str
#
# reason:
# <StringArray>
# ['course', 'other', 'home', 'reputation']
# Length: 4, dtype: str
#
# guardian:
# <StringArray>
# ['mother', 'father', 'other']
# Length: 3, dtype: str

# %%
numerical_columns = [
    "age", "Medu", "Fedu", "studytime",
    "failures", "absences", "G1", "G2", "G3"
]

df[numerical_columns].describe()
# Out:
#               age        Medu        Fedu   studytime    failures    absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    2.035443    0.334177    5.708861   10.908861   10.713924   10.415190
# std      1.276043    1.094735    1.088201    0.839240    0.743651    8.003096    3.319195    3.761505    4.581443
# min     15.000000    0.000000    0.000000    1.000000    0.000000    0.000000    3.000000    0.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    0.000000    0.000000    8.000000    9.000000    8.000000
# 50%     17.000000    3.000000    2.000000    2.000000    0.000000    4.000000   11.000000   11.000000   11.000000
# 75%     18.000000    4.000000    3.000000    2.000000    0.000000    8.000000   13.000000   13.000000   14.000000
# ...

# %%
# Check data types

print("Data types of each column:")
print(df.dtypes)
# Out:
# Data types of each column:
# school          str
# sex             str
# age           int64
# address         str
# famsize         str
# Pstatus         str
# Medu          int64
# Fedu          int64
# Mjob            str
# Fjob            str
# reason          str
# guardian        str
# traveltime    int64
# studytime     int64
# failures      int64
# schoolsup       str
# famsup          str
# paid            str
# activities      str
# nursery         str
# higher          str
# internet        str
# romantic        str
# famrel        int64
# freetime      int64
# goout         int64
# Dalc          int64
# Walc          int64
# health        int64
# absences      int64
# G1            int64
# G2            int64
# G3            int64
# dtype: object

# %%
# Check unique values in categorical columns

categorical_columns = [
    "school", "sex", "address", "famsize",
    "Pstatus", "Mjob", "Fjob", "reason", "guardian"
]

for column in categorical_columns:
    print(f"\n{column}:")
    print(df[column].unique())
# Out:
# school:
# <StringArray>
# ['GP', 'MS']
# Length: 2, dtype: str
#
# sex:
# <StringArray>
# ['F', 'M']
# Length: 2, dtype: str
#
# address:
# <StringArray>
# ['U', 'R']
# Length: 2, dtype: str
#
# famsize:
# <StringArray>
# ['GT3', 'LE3']
# Length: 2, dtype: str
#
# Pstatus:
# <StringArray>
# ['A', 'T']
# Length: 2, dtype: str
#
# Mjob:
# <StringArray>
# ['at_home', 'health', 'other', 'services', 'teacher']
# Length: 5, dtype: str
#
# Fjob:
# <StringArray>
# ['teacher', 'other', 'services', 'health', 'at_home']
# Length: 5, dtype: str
#
# reason:
# <StringArray>
# ['course', 'other', 'home', 'reputation']
# Length: 4, dtype: str
#
# guardian:
# <StringArray>
# ['mother', 'father', 'other']
# Length: 3, dtype: str

# %%
# Check numerical columns for possible outliers

numerical_columns = [
    "age", "Medu", "Fedu", "studytime",
    "failures", "absences", "G1", "G2", "G3"
]

df[numerical_columns].describe()
# Out:
#               age        Medu        Fedu   studytime    failures    absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    2.035443    0.334177    5.708861   10.908861   10.713924   10.415190
# std      1.276043    1.094735    1.088201    0.839240    0.743651    8.003096    3.319195    3.761505    4.581443
# min     15.000000    0.000000    0.000000    1.000000    0.000000    0.000000    3.000000    0.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    0.000000    0.000000    8.000000    9.000000    8.000000
# 50%     17.000000    3.000000    2.000000    2.000000    0.000000    4.000000   11.000000   11.000000   11.000000
# 75%     18.000000    4.000000    3.000000    2.000000    0.000000    8.000000   13.000000   13.000000   14.000000
# ...

# %%
# Check for outliers in absences using the IQR method

Q1 = df["absences"].quantile(0.25)
Q3 = df["absences"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[
    (df["absences"] < lower_bound) |
    (df["absences"] > upper_bound)
]

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower bound:", lower_bound)
print("Upper bound:", upper_bound)
print("Number of absence outliers:", len(outliers))
# Out:
# Q1: 0.0
# Q3: 8.0
# IQR: 8.0
# Lower bound: -12.0
# Upper bound: 20.0
# Number of absence outliers: 15

# %%
# Flag absence outliers without deleting them

df["absence_outlier"] = (
    (df["absences"] < lower_bound) |
    (df["absences"] > upper_bound)
)

print("Number of flagged absence outliers:", df["absence_outlier"].sum())
# Out:
# Number of flagged absence outliers: 15

# %% [markdown]
# ## Data Cleaning Summary
#
# - Missing values: 0 missing values were found, so no missing-value treatment was required.
# - Duplicate records: 0 duplicate rows were found, so no records were removed.
# - Data types: The data types were appropriate for the variables, so no conversion was required.
# - Categorical values: The selected categorical columns were checked and no obvious inconsistent values were found.
# - Outliers: 15 potential outliers were identified in the `absences` column using the IQR method. These observations were flagged but retained because high absence values can represent valid student records. No rows were deleted.

# %%
# EDA Question 1: Gender distribution

gender_counts = df["sex"].value_counts()

print("Number of students by gender:")
print(gender_counts)
# Out:
# Number of students by gender:
# sex
# F    208
# M    187
# Name: count, dtype: int64

# %%
# Calculate gender percentages

gender_percentages = df["sex"].value_counts(normalize=True) * 100

print("Percentage of students by gender:")
print(gender_percentages.round(2))
# Out:
# Percentage of students by gender:
# sex
# F    52.66
# M    47.34
# Name: proportion, dtype: float64

# %%
# EDA Question 2: Average final grade

average_g3 = df["G3"].mean()

print("Average final grade (G3):", round(average_g3, 2))
# Out:
# Average final grade (G3): 10.42

# %%
# Minimum and maximum final grades

print("Minimum final grade:", df["G3"].min())
print("Maximum final grade:", df["G3"].max())
# Out:
# Minimum final grade: 0
# Maximum final grade: 20

# %% [markdown]
# average_g3 = df["G3"].mean()
#
# print("Average final grade (G3):", round(average_g3, 2))

# %% [markdown]
# ### Interpretation
#
# The average final grade (G3) of the 395 students is 10.42 out of 20. The minimum final grade is 0, while the maximum final grade is 20. This shows that the dataset contains students across the full final-grade range.

# %%
# EDA Question 3: Average final grade by gender

gender_g3 = df.groupby("sex")["G3"].mean().round(2)

print("Average final grade by gender:")
print(gender_g3)
# Out:
# Average final grade by gender:
# sex
# F     9.97
# M    10.91
# Name: G3, dtype: float64

# %% [markdown]
# ### Interpretation
#
# The average final grade for female students is 9.97, while the average final grade for male students is 10.91. In this dataset, the difference between the two group averages is 0.94 grade points.

# %%
# Bar chart: Average final grade by gender

gender_g3.plot(kind="bar")

plt.title("Average Final Grade by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Final Grade (G3)")
plt.xticks(rotation=0)
plt.ylim(0, 20)
plt.show()

# %% [markdown]
# ### Visualization Interpretation
#
# The bar chart compares the average final grade (G3) between female and male students. The male group has an average G3 of 10.91, while the female group has an average G3 of 9.97. The chart makes the difference between the two group averages easy to compare.

# %%
# EDA Question 4: Study time and final grade

studytime_g3 = df.groupby("studytime")["G3"].mean().round(2)

print("Average final grade by study time:")
print(studytime_g3)
# Out:
# Average final grade by study time:
# studytime
# 1    10.05
# 2    10.17
# 3    11.40
# 4    11.26
# Name: G3, dtype: float64

# %%
# Line chart: Average final grade by study time

plt.plot(
    studytime_g3.index,
    studytime_g3.values,
    marker="o"
)

plt.title("Average Final Grade by Study Time")
plt.xlabel("Study Time Category")
plt.ylabel("Average Final Grade (G3)")
plt.xticks(studytime_g3.index)
plt.ylim(0, 20)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Interpretation
#
# The line chart shows the relationship between study time and average final grade. The average final grade increases from study-time category 1 to category 3. Category 3 has the highest average final grade, while category 4 shows a small decrease compared with category 3. This describes the pattern observed in this dataset and does not by itself establish causation.

# %%
# EDA Question 5: Absences and final grade

absence_g3_correlation = df["absences"].corr(df["G3"])

print("Correlation between absences and final grade:", round(absence_g3_correlation, 2))
# Out:
# Correlation between absences and final grade: 0.03

# %%
# Scatter plot: Absences vs Final Grade

plt.scatter(df["absences"], df["G3"])

plt.title("Absences vs Final Grade")
plt.xlabel("Number of Absences")
plt.ylabel("Final Grade (G3)")
plt.show()

# %% [markdown]
# absence_g3_correlation = df["absences"].corr(df["G3"])
#
# print("Correlation between absences and final grade:", round(absence_g3_correlation, 2))

# %% [markdown]
# ### Interpretation
#
# The correlation between absences and final grade (G3) is 0.03, which is very close to zero. This indicates that there is very little linear relationship between the number of absences and final grade in this dataset. The scatter plot also shows that students with different numbers of absences have a wide range of final grades.

# %%
# EDA Question 6: Internet access and final grade

internet_g3 = df.groupby("internet")["G3"].mean().round(2)

print("Average final grade by internet access:")
print(internet_g3)
# Out:
# Average final grade by internet access:
# internet
# no      9.41
# yes    10.62
# Name: G3, dtype: float64

# %% [markdown]
# ### Interpretation
#
# Students with internet access have an average final grade (G3) of 10.62, while students without internet access have an average of 9.41. The difference between the two group averages is 1.21 grade points. This describes an association in this dataset and does not establish that internet access causes higher grades.

# %%
# Box plot: Final grade by internet access

df.boxplot(column="G3", by="internet")

plt.title("Final Grade by Internet Access")
plt.suptitle("")
plt.xlabel("Internet Access")
plt.ylabel("Final Grade (G3)")
plt.show()

# %% [markdown]
# ### Visualization Interpretation
#
# The box plot compares the distribution of final grades between students with and without internet access. The internet-access group has a higher median final grade and a somewhat higher overall distribution of grades. Both groups contain students with a final grade of 0.

# %% [markdown]
# # EDA Question 7: Mother's education and final grade
#
# medu_g3 = df.groupby("Medu")["G3"].mean().round(2)
#
# print("Average final grade by mother's education level:")
# print(medu_g3)

# %% [markdown]
# ### Interpretation
#
# The average final grade varies across the mother's education-level categories. The highest average G3 is 13.00 for category 0, while the lowest is 8.68 for category 1. The averages for categories 2, 3, and 4 are 9.73, 10.30, and 11.76 respectively. Therefore, the relationship is not strictly increasing across all education categories.

# %%
# Bar chart: Mother's education level vs final grade

medu_g3.plot(kind="bar")

plt.title("Average Final Grade by Mother's Education Level")
plt.xlabel("Mother's Education Level (Medu)")
plt.ylabel("Average Final Grade (G3)")
plt.xticks(rotation=0)
plt.ylim(0, 20)
plt.show()

# %% [markdown]
# ### Visualization Interpretation
#
# The bar chart shows that the average final grade differs across the mother's education-level categories. Category 0 has the highest average, while category 1 has the lowest average. The remaining categories show different average grade levels.

# %% [markdown]
# # EDA Question 8: Previous failures and final grade
#
# failures_g3 = df.groupby("failures")["G3"].mean().round(2)
#
# print("Average final grade by number of previous failures:")
# print(failures_g3)

# %% [markdown]
# ### Interpretation
#
# The average final grade varies with the number of previous failures. Students with 0 previous failures have an average G3 of 11.25, while students with 1, 2, and 3 previous failures have average G3 values of 8.12, 6.24, and 5.69 respectively. In this dataset, higher numbers of previous failures are associated with lower average final grades.

# %%
# Histogram: Final grade distribution by previous failures

import seaborn as sns

sns.histplot(
    data=df,
    x="G3",
    hue="failures",
    bins=10,
    multiple="stack"
)

plt.title("Final Grade Distribution by Previous Failures")
plt.xlabel("Final Grade (G3)")
plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
# ### Visualization Interpretation
#
# The histogram shows the distribution of final grades across different previous-failure groups. The distribution differs between the groups, with students having more previous failures generally appearing at lower final-grade values. This supports the difference in group averages observed above.

# %%
# EDA Question 9: School and final grade

school_g3 = df.groupby("school")["G3"].mean().round(2)

print("Average final grade by school:")
print(school_g3)
# Out:
# Average final grade by school:
# school
# GP    10.49
# MS     9.85
# Name: G3, dtype: float64

# %% [markdown]
# ### Interpretation
#
# The average final grade for students in school GP is 10.49, while the average for students in school MS is 9.85. The difference between the two school averages is 0.64 grade points. This describes a difference in this dataset and does not by itself explain why the difference exists.

# %%
# Pie chart: Student distribution by school

school_counts = df["school"].value_counts()

plt.pie(
    school_counts.values,
    labels=school_counts.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Student Distribution by School")
plt.show()

# %% [markdown]
# ### Visualization Interpretation
#
# The pie chart shows that 88.4% of the students in the dataset belong to school GP, while 11.6% belong to school MS. Therefore, the dataset contains substantially more students from GP than MS.

# %%
# EDA Question 10: Correlation between G1, G2 and G3

grade_correlation = df[["G1", "G2", "G3"]].corr()

print("Correlation matrix:")
print(grade_correlation.round(2))
# Out:
# Correlation matrix:
#       G1    G2   G3
# G1  1.00  0.85  0.8
# G2  0.85  1.00  0.9
# G3  0.80  0.90  1.0

# %% [markdown]
# ### Interpretation
#
# The correlation matrix shows strong positive relationships among G1, G2, and G3. G1 and G2 have a correlation of 0.85, G1 and G3 have a correlation of 0.80, and G2 and G3 have the highest correlation of 0.90. This indicates that students' grades across these assessment periods tend to move together in this dataset. Correlation describes association and does not establish causation.

# %%
# Heatmap: Correlation between grades

sns.heatmap(
    grade_correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Between G1, G2 and G3")
plt.show()

# %% [markdown]
# ### Visualization Interpretation
#
# The heatmap visually represents the correlations among G1, G2, and G3. The darkest/highest correlation is between G2 and G3, with a value of 0.90. The other grade pairs also show strong positive correlations.

# %% [markdown]
# # Key Findings
#
# 1. The dataset contains 395 students, with 52.66% female students and 47.34% male students.
# 2. The average final grade (G3) is 10.42 out of 20.
# 3. The average final grade differs by gender, with averages of 9.97 for females and 10.91 for males.
# 4. Average final grades generally increase from study-time category 1 to category 3, with a small decrease at category 4.
# 5. The correlation between absences and final grade is 0.03, indicating very little linear relationship.
# 6. Students with internet access have an average G3 of 10.62, compared with 9.41 for students without internet access.
# 7. Average final grades vary across the mother's education-level categories.
# 8. Students with more previous failures have lower average final grades in this dataset.
# 9. The average final grade is 10.49 for GP and 9.85 for MS.
# 10. G1, G2, and G3 have strong positive correlations, with the highest correlation being 0.90 between G2 and G3.

# %%
# Conclusion

The exploratory data analysis provided an overview of student performance and several factors associated with final grades. The analysis included gender, study time, absences, internet access, mother's education level, previous failures, school, and relationships among assessment grades.

The dataset contained no missing values or duplicate rows. Fifteen potential outliers were identified in the absences column using the IQR method, but they were retained because they may represent valid student records.

The analysis showed noticeable differences in average final grades across several groups. Previous failures showed a clear negative association with average final grade, while G1, G2, and G3 showed strong positive correlations. Overall, the EDA helped identify patterns and relationships within the student performance dataset.
# Out:
#   Cell In[51], line 3
#     The exploratory data analysis provided an overview of student performance and several factors associated with final grades. The analysis included gender, study time, absences, internet access, mother's education level, previous failures, school, and relationships among assessment grades.
#                                                                                                                                                                                                            ^
# SyntaxError: unterminated string literal (detected at line 3)

# %% [markdown]
# # Conclusion
#
# The exploratory data analysis provided an overview of student performance and several factors associated with final grades. The analysis included gender, study time, absences, internet access, mother's education level, previous failures, school, and relationships among assessment grades.
#
# The dataset contained no missing values or duplicate rows. Fifteen potential outliers were identified in the absences column using the IQR method, but they were retained because they may represent valid student records.
#
# The analysis showed noticeable differences in average final grades across several groups. Previous failures showed a clear negative association with average final grade, while G1, G2, and G3 showed strong positive correlations. Overall, the EDA helped identify patterns and relationships within the student performance dataset.
